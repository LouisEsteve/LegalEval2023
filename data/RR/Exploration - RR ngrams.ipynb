# %% [markdown]
# # RR Gensim Tfidf

# %%
import os
import re

# %%
import string

# %%
import pandas as pd
import numpy as np

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
stopwords = nlp.Defaults.stop_words

# %% [markdown]
# ## Data

# %%
DIR = r"C:\Users\jokkl\Documents\Masters\S3\Projet en TAL\Data\CSV DB"
train = os.listdir(DIR)[3]
train
# Out:
# '20221010 195911 RR_Benchmark_TRAIN.csv'

# %%
df = pd.read_csv(DIR + os.sep + train, sep=";", encoding="UTF-8")

# %%
# Cleaning
def process_token(text):
    text = text.lower()
    for char in string.punctuation:
        text = text.replace(char, '')
    # text = text.replace(re.escape(string.punctuation), '')
    # text = re.sub(re.escape(string.punctuation), '', text)
    tokens = text.split(' ')
    for token in tokens:
        token = re.sub(re.escape(string.punctuation), '', token)
        if len(token) < 4 or not(token.isalpha()):
            tokens.remove(token)
    clean = ' '.join(token for token in tokens)
    return clean

# %%
df['cleaned'] = df['text'].apply(process_token)

# %%
df.isna().sum()
# Out:
# doc_id       0
# result_id    0
# text         0
# RR           0
# cleaned      0
# dtype: int64

# %%
RR_types = df['RR'].unique()
RR_types
# Out:
# array(['PREAMBLE', 'NONE', 'FAC', 'ARG_RESPONDENT', 'RLC',
#        'ARG_PETITIONER', 'ANALYSIS', 'PRE_RELIED', 'RATIO', 'RPC',
#        'ISSUE', 'STA', 'PRE_NOT_RELIED'], dtype=object)

# %% [markdown]
# ## N-grams

# %%
def get_n_grams(text, ngram=1):
    words = [word for word in text.split(' ') if word.isalpha() and word not in set(stopwords) and word!='']
    # print('Sentence:', words)
    temp = zip(*[words[i:] for i in range(0, ngram)])
    ngrams = [' '.join(ngram) for ngram in temp]
    return ngrams

# %% [markdown]
# ### Unigram

# %%
ug = df

# %%
ug['ngrams'] = ug['cleaned'].apply(get_n_grams, 1)

# %%
ug.head(5)
# Out:
#    doc_id                         result_id  \
# 0    1735  d7a902fe9c23417499a7ef782f9fbdeb
# 1    1735  8d41599e98424d9480c25109556a7d14
# 2    1735  e501424117da40a7935c2d9f2fb2fe38
# 3    1735  4825806388fe43d39f73354b10b5b32d
# 4    1735  d6893a25f82948f8be17fc9e876fb716
#
#                                                 text        RR  \
# 0        IN THE HIGH COURT OF KARNATAKA,         ...  PREAMBLE
# 1        BEFORETHE HON'BLE MR.JUSTICE ANAND BYRAR...  PREAMBLE
# 2  This Criminal Appeal is filed under Section 37...  PREAMBLE
# 3         This appeal coming on for hearing this ...  PREAMBLE
# 4         Heard the learned Counsel for the appel...      NONE
#
#                                              cleaned  \
# 0  high court karnataka        circuit bench gulb...
# 1  beforethe honble mrjustice anand byrareddy cri...
# 2  this criminal appeal filed under section theco...
# 3  this appeal coming for hearing this courtdeliv...
# 4     heard learned counsel the appellant the lea...
#
#                                               ngrams  \
# 0  [high, court, karnataka, circuit, bench, gulba...
# 1  [beforethe, honble, mrjustice, anand, byraredd...
# 2  [criminal, appeal, filed, section, thecode, cr...
# 3  [appeal, coming, hearing, courtdelivered, foll...
# 4  [heard, learned, counsel, appellant, learned, ...
#
#                                                 test      PREDICTION
# 0  [PRE_NOT_RELIED, PREAMBLE, NONE, FAC, RLC, ANA...  PRE_NOT_RELIED
# 1  [PREAMBLE, NONE, FAC, STA, ARG_RESPONDENT, RLC...        PREAMBLE
# 2  [PREAMBLE, RPC, NONE, FAC, RLC, ARG_RESPONDENT...        PREAMBLE
# 3  [PREAMBLE, NONE, RLC, RPC, FAC, ARG_PETITIONER...        PREAMBLE
# 4  [NONE, ARG_RESPONDENT, ARG_PETITIONER, RLC, RA...            NONE

# %%
from collections import defaultdict

# %%
ngram_counts = {x:defaultdict(lambda: 0) for x in RR_types}

# %%
for label, ddict in ngram_counts.items():
    print('Processing:', label)
    ngram_list = df[df['RR']==label].ngrams
    for sublist in ngram_list:
        for item in sublist:
            ddict[item] += 1
# Out:
# Processing: PREAMBLE
# Processing: NONE
# Processing: FAC
# Processing: ARG_RESPONDENT
# Processing: RLC
# Processing: ARG_PETITIONER
# Processing: ANALYSIS
# Processing: PRE_RELIED
# Processing: RATIO
# Processing: RPC
# Processing: ISSUE
# Processing: STA
# Processing: PRE_NOT_RELIED

# %%
ngrams = pd.DataFrame(ngram_counts)
ngrams.replace(np.nan, 0)
ngrams = ngrams.rename_axis('word').reset_index()

# %%
ngrams.head(5)
# Out:
#         word  PREAMBLE   NONE    FAC  ARG_RESPONDENT    RLC  ARG_PETITIONER  \
# 0       high     261.0   75.0  242.0            26.0  159.0            41.0
# 1      court     524.0  261.0  673.0           141.0  315.0           275.0
# 2  karnataka      91.0    2.0   26.0             5.0    4.0            14.0
# 3    circuit       6.0    NaN    NaN             NaN    NaN             NaN
# 4      bench      46.0    1.0   24.0             5.0   26.0            15.0
#
#    ANALYSIS  PRE_RELIED  RATIO    RPC  ISSUE    STA  PRE_NOT_RELIED
# 0     500.0       159.0   53.0   55.0   26.0   37.0            28.0
# 1    1720.0       627.0  202.0  242.0   78.0  177.0            74.0
# 2      31.0        12.0    1.0    5.0    2.0    2.0             2.0
# 3       1.0         NaN    NaN    NaN    NaN    NaN             NaN
# 4      65.0        42.0    3.0    3.0    2.0    NaN            19.0

# %%
top_1grams = {x:defaultdict(lambda: 0) for x in RR_types}

# %%
for col in ngrams.columns[1:]:
    ng_col = ngrams[['word', col]]
    desc = ng_col.sort_values(by=[col], ascending=False)
    desc = desc.dropna()
    descriptors = desc['word'].tolist()[:20]
    top_1grams[col] = {y:0 for y in descriptors}

# %%
top_1grams
# Out:
# {'PREAMBLE': {'court': 0,
#   'high': 0,
#   'appeal': 0,
#   'years': 0,
#   'state': 0,
#   'appellant': 0,
#   'criminal': 0,
#   'judgment': 0,
#   'case': 0,
#   'section': 0,
#   'respondent': 0,
#   'commissioner': 0,
#   'order': 0,
#   'incometax': 0,
#   'income': 0,
#   'date': 0,
#   'dated': 0,
#   'accused': 0,
#   'aged': 0,
#   'advocate': 0},
#  'NONE': {'court': 0,
#   'signature': 0,
#   'judgment': 0,
#   'list': 0,
#   'judge': 0,
#   'appeal': 0,
#   'order': 0,
#   'learned': 0,
#   'dated': 0,
#   'civil': 0,
#   'criminal': 0,
#   'respondent': 0,
#   'high': 0,
#   'counsel': 0,
#   'heard': 0,
#   'appellate': 0,
#   'jurisdiction': 0,
#   'delivered': 0,
#   'prosecution': 0,
#   'appellant': 0},
#  'FAC': {'accused': 0,
#   'court': 0,
#   'section': 0,
#   'order': 0,
#   'appellant': 0,
#   'case': 0,
#   'said': 0,
#   'filed': 0,
#   'assessee': 0,
#   'appeal': 0,
#   'dated': 0,
#   'police': 0,
#   'respondent': 0,
#   'deceased': 0,
#   'house': 0,
#   'income': 0,
#   'petitioner': 0,
#   'complainant': 0,
#   'high': 0,
#   'stated': 0},
#  'ARG_RESPONDENT': {'learned': 0,
#   'accused': 0,
#   'court': 0,
#   'case': 0,
#   'counsel': 0,
#   'submitted': 0,
#   'evidence': 0,
#   'section': 0,
#   'state': 0,
#   'respondent': 0,
#   'petitioner': 0,
#   'contended': 0,
#   'said': 0,
#   'prosecution': 0,
#   'hand': 0,
#   'order': 0,
#   'petitioners': 0,
#   'suit': 0,
#   'appellant': 0,
#   'bail': 0},
#  'RLC': {'court': 0,
#   'section': 0,
#   'high': 0,
#   'accused': 0,
#   'order': 0,
#   'imprisonment': 0,
#   'case': 0,
#   'offence': 0,
#   'appellant': 0,
#   'trial': 0,
#   'dated': 0,
#   'appeal': 0,
#   'learned': 0,
#   'held': 0,
#   'judgment': 0,
#   'sentenced': 0,
#   'code': 0,
#   'judge': 0,
#   'tribunal': 0,
#   'fine': 0},
#  'ARG_PETITIONER': {'court': 0,
#   'learned': 0,
#   'counsel': 0,
#   'case': 0,
#   'petitioner': 0,
#   'submitted': 0,
#   'section': 0,
#   'accused': 0,
#   'state': 0,
#   'evidence': 0,
#   'appellant': 0,
#   'said': 0,
#   'contended': 0,
#   'assessee': 0,
#   'order': 0,
#   'petitioners': 0,
#   'income': 0,
#   'prosecution': 0,
#   'judgment': 0,
#   'india': 0},
#  'ANALYSIS': {'accused': 0,
#   'court': 0,
#   'case': 0,
#   'evidence': 0,
#   'section': 0,
#   'said': 0,
#   'assessee': 0,
#   'stated': 0,
#   'prosecution': 0,
#   'order': 0,
#   'appellant': 0,
#   'high': 0,
#   'officer': 0,
#   'income': 0,
#   'house': 0,
#   'time': 0,
#   'question': 0,
#   'act': 0,
#   'view': 0,
#   'assessment': 0},
#  'PRE_RELIED': {'court': 0,
#   'case': 0,
#   'section': 0,
#   'state': 0,
#   'held': 0,
#   'high': 0,
#   'accused': 0,
#   'evidence': 0,
#   'income': 0,
#   'question': 0,
#   'act': 0,
#   'decision': 0,
#   'view': 0,
#   'assessee': 0,
#   'commissioner': 0,
#   'said': 0,
#   'incometax': 0,
#   'supra': 0,
#   'law': 0,
#   'power': 0},
#  'RATIO': {'court': 0,
#   'case': 0,
#   'view': 0,
#   'accused': 0,
#   'section': 0,
#   'evidence': 0,
#   'prosecution': 0,
#   'appellant': 0,
#   'trial': 0,
#   'offence': 0,
#   'high': 0,
#   'opinion': 0,
#   'circumstances': 0,
#   'petitioner': 0,
#   'question': 0,
#   'order': 0,
#   'facts': 0,
#   'failed': 0,
#   'present': 0,
#   'learned': 0},
#  'RPC': {'appeal': 0,
#   'court': 0,
#   'order': 0,
#   'shall': 0,
#   'dismissed': 0,
#   'allowed': 0,
#   'case': 0,
#   'accordingly': 0,
#   'section': 0,
#   'accused': 0,
#   'bail': 0,
#   'petitioner': 0,
#   'appellant': 0,
#   'costs': 0,
#   'aside': 0,
#   'set': 0,
#   'judgment': 0,
#   'petition': 0,
#   'respondent': 0,
#   'sentence': 0},
#  'ISSUE': {'case': 0,
#   'accused': 0,
#   'court': 0,
#   'section': 0,
#   'facts': 0,
#   'order': 0,
#   'circumstances': 0,
#   'tribunal': 0,
#   'following': 0,
#   'assessee': 0,
#   'law': 0,
#   'question': 0,
#   'points': 0,
#   'plaintiff': 0,
#   'consideration': 0,
#   'proves': 0,
#   'committed': 0,
#   'holding': 0,
#   'said': 0,
#   'place': 0},
#  'STA': {'section': 0,
#   'shall': 0,
#   'court': 0,
#   'person': 0,
#   'subsection': 0,
#   'case': 0,
#   'offence': 0,
#   'income': 0,
#   'cooperative': 0,
#   'act': 0,
#   'time': 0,
#   'order': 0,
#   'state': 0,
#   'death': 0,
#   'government': 0,
#   'clause': 0,
#   'reads': 0,
#   'provided': 0,
#   'society': 0,
#   'goods': 0},
#  'PRE_NOT_RELIED': {'court': 0,
#   'case': 0,
#   'state': 0,
#   'high': 0,
#   'decision': 0,
#   'held': 0,
#   'commissioner': 0,
#   'bench': 0,
#   'section': 0,
#   'judgment': 0,
#   'assessee': 0,
#   'evidence': 0,
#   'incometax': 0,
#   'constitution': 0,
#   'question': 0,
#   'declaration': 0,
#   'said': 0,
#   'statement': 0,
#   'entries': 0,
#   'bank': 0}}

# %%
import copy

# %%
def evaluate_class(text):
    ngram_list = copy.deepcopy(top_1grams)
    for label, ngrams in ngram_list.items():
        for word in text:
            if word in ngrams.keys():
                ngrams[word] += 1
    count_raw = defaultdict()
    for label, ngrams in ngram_list.items():
        count_raw[label] = sum(1 for item in ngrams.values() if item!=0)
    total = sum(count_raw.values())
    count = {k:round(v/total, 2) for k,v in count_raw.items() if total!=0}
    count = sorted(count, key=count.get, reverse=True)
    return count

# %%
def get_prediction(list_obj):
    if list_obj:
        label = list_obj[0]
    else:
        label = 'NONE'
    return label

# %%
df['test'] = df['ngrams'].apply(evaluate_class)

# %%
df['PREDICTION'] = df['test'].apply(get_prediction)

# %%
pd.reset_option('max_columns')
pd.reset_option('max_rows')
df.head(10)
# Out:
#    doc_id                         result_id  \
# 0    1735  d7a902fe9c23417499a7ef782f9fbdeb
# 1    1735  8d41599e98424d9480c25109556a7d14
# 2    1735  e501424117da40a7935c2d9f2fb2fe38
# 3    1735  4825806388fe43d39f73354b10b5b32d
# 4    1735  d6893a25f82948f8be17fc9e876fb716
# 5    1735  5ffc5502c95d45d7aae96937f128fdcb
# 6    1735  afca23e571ad475d89a6fa226ca771bd
# 7    1735  7781f76712ed452dab7119e58f514065
# 8    1735  13ad25d88e1a4cf7b1a0f8e49561acb5
# 9    1735  bdd429d80cb149b280248e4e26d3f86d
#
#                                                 text        RR  \
# 0        IN THE HIGH COURT OF KARNATAKA,         ...  PREAMBLE
# 1        BEFORETHE HON'BLE MR.JUSTICE ANAND BYRAR...  PREAMBLE
# 2  This Criminal Appeal is filed under Section 37...  PREAMBLE
# 3         This appeal coming on for hearing this ...  PREAMBLE
# 4         Heard the learned Counsel for the appel...      NONE
# 5  2. The accused is in appeal in the following c...       FAC
# 6  The complainant Sonabai was a resident of Hanu...       FAC
# 7      She had two daughters, Laxmibai and Sangeeta.       FAC
# 8  She had lost her husband about 12 years prior ...       FAC
# 9  She had performed the marriage of her elder da...       FAC
#
#                                              cleaned  \
# 0  high court karnataka        circuit bench gulb...
# 1  beforethe honble mrjustice anand byrareddy cri...
# 2  this criminal appeal filed under section theco...
# 3  this appeal coming for hearing this courtdeliv...
# 4     heard learned counsel the appellant the lea...
# 5  accused appeal in following circumstances appe...
# 6  complainant sonabai a resident hanumantwadi ba...
# 7                    had daughters laxmibai sangeeta
# 8   had lost husband about years prior the complaint
# 9  had performed marriage her elder daughter laxm...
#
#                                               ngrams  \
# 0  [high, court, karnataka, circuit, bench, gulba...
# 1  [beforethe, honble, mrjustice, anand, byraredd...
# 2  [criminal, appeal, filed, section, thecode, cr...
# 3  [appeal, coming, hearing, courtdelivered, foll...
# 4  [heard, learned, counsel, appellant, learned, ...
# 5  [accused, appeal, following, circumstances, ap...
# 6  [complainant, sonabai, resident, hanumantwadi,...
# 7                    [daughters, laxmibai, sangeeta]
# 8           [lost, husband, years, prior, complaint]
# 9  [performed, marriage, elder, daughter, laxmi, ...
#
#                                                 test      PREDICTION
# 0  [PRE_NOT_RELIED, PREAMBLE, NONE, FAC, RLC, ANA...  PRE_NOT_RELIED
# 1  [PREAMBLE, NONE, FAC, STA, ARG_RESPONDENT, RLC...        PREAMBLE
# 2  [PREAMBLE, RPC, NONE, FAC, RLC, ARG_RESPONDENT...        PREAMBLE
# 3  [PREAMBLE, NONE, RLC, RPC, FAC, ARG_PETITIONER...        PREAMBLE
# 4  [NONE, ARG_RESPONDENT, ARG_PETITIONER, RLC, RA...            NONE
# 5  [RLC, PREAMBLE, FAC, RATIO, RPC, ISSUE, NONE, ...             RLC
# 6  [FAC, PREAMBLE, NONE, ARG_RESPONDENT, RLC, ARG...             FAC
# 7                                                 []            NONE
# 8  [PREAMBLE, NONE, FAC, ARG_RESPONDENT, RLC, ARG...        PREAMBLE
# 9  [PREAMBLE, NONE, FAC, ARG_RESPONDENT, RLC, ARG...        PREAMBLE

# %% [markdown]
# ## Evaluation

# %%
from sklearn import metrics

# %%
classification_report = metrics.classification_report(df['RR'], df['PREDICTION'], zero_division=1, digits=3)
print(classification_report)
# Out:
#                 precision    recall  f1-score   support
#
#       ANALYSIS      0.537     0.105     0.176     10695
# ARG_PETITIONER      0.175     0.056     0.085      1315
# ARG_RESPONDENT      0.089     0.309     0.138       698
#            FAC      0.370     0.254     0.301      5744
#          ISSUE      0.165     0.332     0.220       367
#           NONE      0.126     0.728     0.215      1423
#       PREAMBLE      0.246     0.314     0.276      4167
# PRE_NOT_RELIED      0.077     0.184     0.108       158
#     PRE_RELIED      0.264     0.171     0.208      1431
#          RATIO      0.100     0.184     0.130       674
#            RLC      0.146     0.291     0.194       752
#            RPC      0.452     0.355     0.398      1081
#            STA      0.191     0.372     0.253       481
#
#       accuracy                          0.225     28986
#      macro avg      0.226     0.281     0.208     28986
#   weighted avg      0.365     0.225     0.223     28986

# %% [markdown]
# ### Bigram
